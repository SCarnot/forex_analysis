# %%
import pandas as pd
import numpy as np
import re
from matplotlib import pyplot as plt

# %%
with open('../data/XXBTZEUR.csv') as f:
    # Reading header of numpy file
    header = f.readline()[2:-1]
    # Converting it from str to a list
    header = [s.strip() for s in re.split(",\s", header)]
df_btc = pd.DataFrame(data=np.loadtxt('../data/XXBTZEUR.csv'), columns=header) 
df_btc
# Out:
#         year  month   day  hour  minute  second     ask     bid  \
# 0     2020.0    9.0  13.0  23.0    10.0    26.0  8721.1  8721.0
# 1     2020.0    9.0  13.0  23.0    10.0    27.0  8721.1  8721.0
# 2     2020.0    9.0  13.0  23.0    10.0    58.0  8721.1  8721.0
# 3     2020.0    9.0  13.0  23.0    11.0    29.0  8720.9  8720.8
# 4     2020.0    9.0  13.0  23.0    11.0    59.0  8720.9  8720.8
# ...      ...    ...   ...   ...     ...     ...     ...     ...
# 1018  2020.0    9.0  14.0   7.0    49.0    56.0  8755.3  8755.2
# 1019  2020.0    9.0  14.0   7.0    50.0    26.0  8755.3  8755.2
# 1020  2020.0    9.0  14.0   7.0    50.0    57.0  8754.8  8754.7
# 1021  2020.0    9.0  14.0   7.0    51.0    28.0  8755.2  8754.4
# 1022  2020.0    9.0  14.0   7.0    51.0    58.0  8759.0  8758.9
#
#       last trade closed       volume  volume weighted average price
# 0                8721.1  2716.737279                     8782.68255
# ...

# %%
with open('../data/forex.csv') as f:
    # Reading header of numpy file
    header = f.readline()[2:-1]
    # Converting it from str to a list
    header = [s.strip() for s in re.split(",\s", header)]
df_forex = pd.DataFrame(data=np.loadtxt('../data/forex.csv'), columns=header) 
df_forex
# Out:
#        year  month   day  hour  minute  second  EUR/USD  EUR/GBP  EUR/JPY  \
# 0    2020.0    9.0  13.0  23.0    13.0    12.0   1.1848   0.9256   125.75
# 1    2020.0    9.0  13.0  23.0    13.0    21.0   1.1848   0.9256   125.75
# 2    2020.0    9.0  13.0  23.0    16.0    26.0   1.1848   0.9256   125.75
# 3    2020.0    9.0  13.0  23.0    19.0    37.0   1.1848   0.9256   125.75
# 4    2020.0    9.0  13.0  23.0    22.0    40.0   1.1848   0.9256   125.75
# ..      ...    ...   ...   ...     ...     ...      ...      ...      ...
# 186  2020.0    9.0  14.0   8.0    46.0    56.0   1.1857   0.9240   125.69
# 187  2020.0    9.0  14.0   8.0    50.0     2.0   1.1857   0.9240   125.69
# 188  2020.0    9.0  14.0   8.0    53.0     5.0   1.1860   0.9242   125.70
# 189  2020.0    9.0  14.0   8.0    56.0     7.0   1.1860   0.9234   125.67
# 190  2020.0    9.0  14.0   8.0    59.0    11.0   1.1864   0.9235   125.73
#
#      EUR/CHF  USD/JPY  EUR/DKK  EUR/NOK  EUR/SEK  USD/CAD  USD/HKD  USD/SGD  \
# ...

# %%
plt.show()
plt.plot(df_btc.loc[500:600,'bid'])

# %%
plt.show()
plt.plot(df_forex.loc[140:190,'EUR/USD'])
